# %% [markdown]
# <a href="https://colab.research.google.com/github/alnajenson252dot/ict_assigntment/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# project 1

# %%
#8
def int(self,course_is,name,credits,max_seats):
       self.course_id = course_id
       self.name = name
       self.credits = credits
       self.max_seats = max_seats
       self.seats_taken = 0
       self.students = []
print("course and student classes defined successfully.")
# Out:
# course and student classes defined successfully.

# %%
#QUESTION NUMBER 6

# %%
#6

example_total_score = 4.5
example_correct_answers_count = 2
example_incorrect_answers_count = 1
example_detailed_results = [
    {
        'question_text': 'What is the capital of France?',
        'user_answer': 'Paris',
        'correct_answer': 'Paris',
        'points_awarded': 1.0,
        'outcome': 'Correct'
    },
    {
        'question_text': 'Which planet is known as the Red Planet?',
        'user_answer': 'Jupiter',
        'correct_answer': 'Mars',
        'points_awarded': -0.5,
        'outcome': 'Incorrect'
    },
    {
        'question_text': 'What is the largest ocean on Earth?',
        'user_answer': 'Pacific Ocean',
        'correct_answer': 'Pacific Ocean',
        'points_awarded': 2.0,
        'outcome': 'Correct'
    }
]
