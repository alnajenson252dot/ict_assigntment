# %% [markdown]
# <a href="https://colab.research.google.com/github/alnajenson252dot/ict_assigntment/blob/main/Assignment_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = data.set_index('name')
data.head()
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN      F  Operations    G3                723
# S Kumar         NaN  16000.0      F     Finance    G0                520
# Jack Morgan    32.0  35000.0      M     Finance    G2                674
# Ying Chin      45.0  65000.0      F       Sales    G3                556
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %%
employees_above_700 = data[data['performance_score'] > 700]
display(employees_above_700)
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN      F  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
data =pd.read_csv('/content/employee.csv')

# %%
data.head()
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 636.0+ bytes

# %%
data.describe()
# Out:
#              age        income  performance_score
# count   7.000000      7.000000           9.000000
# mean   40.428571  52857.142857         610.666667
# std    12.204605  26028.372797         235.671912
# min    23.000000  16000.000000          53.000000
# 25%    31.000000  38500.000000         556.000000
# 50%    45.000000  52000.000000         674.000000
# 75%    49.500000  63500.000000         711.000000
# max    54.000000  98000.000000         901.000000

# %%
data.isna().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
x = data.drop('performance_score', axis=1)
y = data['performance_score']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)

# %%
x_test
# Out:
#          name   age   income gender department grade
# 7  Josh Wills  54.0  52000.0      F    Finance    G3
# 1     S Kumar   NaN  16000.0      F    Finance    G0

# %%
high_performance_employees = data[data['performance_score'] > 700]
display(high_performance_employees)
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
filtered_employee =data[(data['performance_score']> 500)&(data['performance_score']<700)]
print(filtered_employee)
# Out:
#             name   age   income gender department grade  performance_score
# 1        S Kumar   NaN  16000.0      F    Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M    Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F      Sales    G3                556
# 5  Satyam Sharma   NaN  62000.0    NaN      Sales    G3                649

# %%
data.isna().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
print("Unique values in 'gender' column:")
print(data['gender'].unique())
# Out:
# Unique values in 'gender' column:
# [nan 'F' 'M']

# %%
data['gender'].fillna(data['gender'].mode()[0], inplace=True)
print('Missing values :', data['gender'].isna().sum())
data_encoded = pd.get_dummies(data, columns=['gender'], drop_first=True)
display(data_encoded.head())
# Out:
# Missing values : 0
# /tmp/ipykernel_11151/3705500081.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['gender'].fillna(data['gender'].mode()[0], inplace=True)
#             name   age   income  department grade  performance_score  gender_M
# 0    Allen Smith  45.0      NaN  Operations    G3                723     False
# 1        S Kumar   NaN  16000.0     Finance    G0                520     False
# 2    Jack Morgan  32.0  35000.0     Finance    G2                674      True
# ...

# %%
sns.boxplot(data['performance_score'])
plt.show()

# %%
sns.boxplot(data['age'])
plt.show()
